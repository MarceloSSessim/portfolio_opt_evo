# %%
# Bibliotecas a serem utilizadas
import random
import numpy as np
import pandas as pd
from deap import algorithms
from deap import base
from deap import creator
from deap import tools
import math
import os
from sklearn.preprocessing import StandardScaler
import hdbscan
from deap.tools import DeltaPenalty
import multiprocessing
from pathos.multiprocessing import ProcessingPool as Pool

# %%
year = 2020
# Caminho da pasta no WSL
folder_path = "/mnt/c/Users/msses/Desktop/ETF/weekly_log_returns"
# Lista os arquivos da pasta que começam com o padrão desejado
arquivos_do_ano = [
    f for f in os.listdir(folder_path)
    if f.startswith(f"weekly_log_returns_{year}_") and f.endswith(".csv")
]

# Carrega e concatena os arquivos em um único DataFrame
df_concatenado = pd.concat(
    [pd.read_csv(os.path.join(folder_path, arquivo)) for arquivo in sorted(arquivos_do_ano)],
    ignore_index=True
)

# Visualiza as primeiras linhas do DataFrame
print(df_concatenado.head())
# Out:
#   ticker  week_start  first_price  last_price  log_return  year  month
# 0   AAAU  2020-01-06      15.6200     15.5700   -0.003206  2020      1
# 1   AAAU  2020-01-13      15.4500     15.5300    0.005165  2020      1
# 2   AAAU  2020-01-20      15.5500     15.6800    0.008325  2020      1
# 3   AAAU  2020-01-27      15.7900     15.8300    0.002530  2020      1
# 4   AADR  2020-01-06      50.7008     51.4471    0.014612  2020      1

# %%
def filtrar_tickers_completos(df):
    """
    Filtra o DataFrame para manter apenas os tickers com o número máximo de observações.

    Parâmetros:
    - df: DataFrame contendo colunas 'ticker'

    Retorna:
    - df_filtrado: DataFrame apenas com os tickers completos
    """
    contagem_por_ticker = df['ticker'].value_counts()
    n_max = contagem_por_ticker.max()
    tickers_completos = contagem_por_ticker[contagem_por_ticker == n_max].index.tolist()
    df_filtrado = df[df['ticker'].isin(tickers_completos)]


    return df_filtrado

def selecionar_tickers_representativos(df_filtrado, num_tickers):
    """
    Aplica HDBSCAN para selecionar os tickers mais representativos com base em seus log_returns.

    Parâmetros:
    - df_filtrado: DataFrame com tickers completos
    - num_tickers: número de tickers representativos a retornar

    Retorna:
    - df_final: DataFrame apenas com os tickers selecionados
    - tickers_selecionados: lista de tickers representativos
    """
    # Pivotar a matriz para ter um vetor de log_return por ticker
    df_pivot = df_filtrado.pivot_table(
        index='ticker',
        columns=['year', 'month', 'week_start'],
        values='log_return'
    ).fillna(0)

    # Padronizar
    X = StandardScaler().fit_transform(df_pivot)

    # Clusterização
    clusterer = hdbscan.HDBSCAN(min_cluster_size=5)
    cluster_labels = clusterer.fit_predict(X)

    # Associar cluster a ticker
    df_clusters = pd.DataFrame({
        'ticker': df_pivot.index,
        'cluster': cluster_labels
    })

    # Selecionar o maior cluster
    maior_cluster = df_clusters['cluster'].value_counts().idxmax()
    tickers_maior_cluster = df_clusters[df_clusters['cluster'] == maior_cluster]['ticker'].tolist()

    # Selecionar os N primeiros tickers do maior cluster
    tickers_selecionados = tickers_maior_cluster[:num_tickers]
    df_final = df_filtrado[df_filtrado['ticker'].isin(tickers_selecionados)]

    print(f"Tickers selecionados: {tickers_selecionados}")

    return df_final, tickers_selecionados

# %%
df = df_concatenado
# =======================
# 1. Filtrar tickers completos
# =======================
contagem_por_ticker = df['ticker'].value_counts()
n_max = contagem_por_ticker.max()

# Filtrar apenas os tickers com número de observações == n_max
tickers_completos = contagem_por_ticker[contagem_por_ticker == n_max].index.tolist()
df_filtrado = df[df['ticker'].isin(tickers_completos)]

print(f"Total de tickers: {df['ticker'].nunique()}")
print(f"Tickers completos restantes: {len(tickers_completos)}")

# =======================
# 2. Aplicar HDBSCAN para selecionar os num_tickers mais representativos
# =======================

# Número desejado de tickers representativos
num_tickers = 30  # ou outro valor que você quiser

# Pivotar para cada linha ser um ticker com colunas de log_returns semanais
df_pivot = df_filtrado.pivot_table(
    index='ticker', 
    columns=['year', 'month', 'week_start'], 
    values='log_return'
).fillna(0)  # Pode usar média ou zero para preencher ausências

# Padronizar os dados
X = StandardScaler().fit_transform(df_pivot)

# Rodar HDBSCAN
clusterer = hdbscan.HDBSCAN(min_cluster_size=5)
cluster_labels = clusterer.fit_predict(X)

# Adicionar os labels ao dataframe original
df_clusters = pd.DataFrame({
    'ticker': df_pivot.index,
    'cluster': cluster_labels
})

# Filtrar o maior cluster (mais representativo)
maior_cluster = df_clusters['cluster'].value_counts().idxmax()
tickers_maior_cluster = df_clusters[df_clusters['cluster'] == maior_cluster]['ticker'].tolist()

# Selecionar os N primeiros tickers do maior cluster
tickers_selecionados = tickers_maior_cluster[:num_tickers]

# Filtrar o DataFrame final
df_final = df_filtrado[df_filtrado['ticker'].isin(tickers_selecionados)]

print(f"Tickers selecionados (representativos): {tickers_selecionados}")
print(len(tickers_selecionados))
# Out:
# Total de tickers: 2223
# Tickers completos restantes: 1900
# Tickers selecionados (representativos): ['AADR', 'ACES', 'ACIO', 'ACSI', 'ACTX', 'ACWF', 'ACWV', 'ADME', 'ADRE', 'AESR', 'AFK', 'AFLG', 'AFTY', 'AGNG', 'AGQ', 'AIA', 'AIEQ', 'AIQ', 'AIRR', 'AIVI', 'ALTY', 'AMJ', 'AMLP', 'AMUB', 'AMZA', 'ANGL', 'AOA', 'AOK', 'AOR', 'ARGT']
# 30
# /home/mssessim/portfolio_opt_evo/myenv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/mssessim/portfolio_opt_evo/myenv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# -------- PARAMETROS --------
BETA = 0.98
CVaR_ALPHA = 0.05
NUM_ATIVOS = 30
POP_SIZE = 1000
N_GEN = 500

# -------- PREPARO DOS DADOS --------
# df_final deve conter: 'ticker', 'week_start', 'log_return', 'first_price', 'last_price'
tickers = df_final['ticker'].unique()
df_pivot = df_final.pivot(index='week_start', columns='ticker', values='log_return').fillna(0)
log_returns = df_pivot[tickers].values  # matriz [T x N]
n_semanas, n_ativos = log_returns.shape

# -------- DEFINIÇÃO DAS FUNÇÕES --------
def avaliar(individuo):
    pesos = np.array(individuo[:n_ativos])
    selecionados = np.array(individuo[n_ativos:])
    pesos = pesos * selecionados

    soma_pesos = pesos.sum()
    if soma_pesos > 0:
        pesos = pesos / soma_pesos

    # ---- RETORNO PONDERADO COM BETA ----
    beta_weights = np.array([BETA**(n_semanas - 1 - i) for i in range(n_semanas)])
    portfolio_returns = log_returns @ pesos
    weighted_return = np.sum(portfolio_returns * beta_weights)

    # ---- CVaR ----
    sorted_returns = np.sort(portfolio_returns)
    index_cut = max(1, int(np.floor(CVaR_ALPHA * len(sorted_returns))))
    cvar = -np.mean(sorted_returns[:index_cut])

    return weighted_return, cvar


def feasible(individuo):
    pesos = np.array(individuo[:n_ativos])
    selecionados = np.array(individuo[n_ativos:])
    pesos = pesos * selecionados

    soma_pesos = pesos.sum()
    num_selecionados = selecionados.sum()
    return soma_pesos==1 and num_selecionados>1

def distance(individuo):
    pesos = np.array(individuo[:n_ativos])
    selecionados = np.array(individuo[n_ativos:])
    pesos = pesos * selecionados
    soma_pesos = pesos.sum()

    return abs(1.0 - soma_pesos)

def custom_mutate(individuo, indpb_float=0.8, indpb_bin=0.9):
    # Mutação dos genes de alocação (contínuos)
    for i in range(n_ativos):
        if np.random.rand() < indpb_float:
            individuo[i] = np.random.uniform(0, 1)

    # Mutação dos genes binários (seleção)
    for i in range(n_ativos, 2 * n_ativos):
        if np.random.rand() < indpb_bin:
            individuo[i] = 1 - individuo[i]  # flip 0↔1

    return individuo,
# -------- DEAP SETUP --------
creator.create("FitnessMulti", base.Fitness, weights=(1.0, -1.0))  # max retorno, min CVaR
creator.create("Individual", list, fitness=creator.FitnessMulti)

toolbox = base.Toolbox()

# Inicialização de genes contínuos (alocação)
toolbox.register("attr_float", lambda: np.random.uniform(0, 1))

# Inicialização de genes binários (seleção)
toolbox.register("attr_bin", lambda: np.random.randint(0, 2))

# Criação de indivíduo
toolbox.register("individual", tools.initCycle, creator.Individual,
                 (toolbox.attr_float,) * n_ativos + (toolbox.attr_bin,) * n_ativos, n=1)

toolbox.register("population", tools.initRepeat, list, toolbox.individual)
penalty = (-1e6, 1e6)  

toolbox.register(
    "evaluate",
    DeltaPenalty(feasible, penalty, distance)(avaliar)
)

toolbox.register("mate", tools.cxUniform, indpb=0.05) 
toolbox.register("mutate", custom_mutate)
toolbox.register("select", tools.selNSGA2)
toolbox.register("map", Pool().map)
# -------- EXECUÇÃO --------
pop = toolbox.population(n=POP_SIZE)
def get_adaptive_probs(gen, ngen,
                       cxpb_start=0.3, cxpb_end=0.1,
                       mutpb_start=0.7, mutpb_end=0.9):
    frac = gen / ngen
    cxpb = cxpb_start + frac * (cxpb_end - cxpb_start)
    mutpb = mutpb_start + frac * (mutpb_end - mutpb_start)
    return cxpb, mutpb

# Avaliar população inicial
invalid_ind = [ind for ind in pop if not ind.fitness.valid]
fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
for ind, fit in zip(invalid_ind, fitnesses):
    ind.fitness.values = fit

# Evolução manual
for gen in range(1, N_GEN + 1):
    cxpb, mutpb = get_adaptive_probs(gen, N_GEN)

    offspring = toolbox.select(pop, len(pop))
    offspring = list(map(toolbox.clone, offspring))

    for i in range(1, len(offspring), 2):
        if np.random.rand() < cxpb:
            toolbox.mate(offspring[i - 1], offspring[i])
            del offspring[i - 1].fitness.values
            del offspring[i].fitness.values

    for mutant in offspring:
        if np.random.rand() < mutpb:
            toolbox.mutate(mutant)
            del mutant.fitness.values

    invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
    fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit

    # Injetar diversidade
    num_novos = int(0.05 * POP_SIZE)
    novos_inds = [toolbox.individual() for _ in range(num_novos)]
    fitnesses = toolbox.map(toolbox.evaluate, novos_inds)
    for ind, fit in zip(novos_inds, fitnesses):
        ind.fitness.values = fit

    pop[:] = tools.selNSGA2(pop + offspring, POP_SIZE)

    print(f"Geração {gen} - cxpb: {cxpb:.2f}, mutpb: {mutpb:.2f}")

# Resultado final
melhores = tools.selBest(pop, k=5)
for i, ind in enumerate(melhores):
    print(f"Indivíduo {i + 1} - Retorno: {avaliar(ind)[0]:.5f}, CVaR: {avaliar(ind)[1]:.5f}")
# Out:
# Geração 1 - cxpb: 0.30, mutpb: 0.70
# Geração 2 - cxpb: 0.30, mutpb: 0.70
# Geração 3 - cxpb: 0.30, mutpb: 0.70
# Geração 4 - cxpb: 0.30, mutpb: 0.70
# Geração 5 - cxpb: 0.30, mutpb: 0.70
# Geração 6 - cxpb: 0.30, mutpb: 0.70
# Geração 7 - cxpb: 0.30, mutpb: 0.70
# Geração 8 - cxpb: 0.30, mutpb: 0.70
# Geração 9 - cxpb: 0.30, mutpb: 0.70
# Geração 10 - cxpb: 0.30, mutpb: 0.70
# Geração 11 - cxpb: 0.30, mutpb: 0.70
# Geração 12 - cxpb: 0.30, mutpb: 0.70
# Geração 13 - cxpb: 0.29, mutpb: 0.71
# Geração 14 - cxpb: 0.29, mutpb: 0.71
# Geração 15 - cxpb: 0.29, mutpb: 0.71
# Geração 16 - cxpb: 0.29, mutpb: 0.71
# Geração 17 - cxpb: 0.29, mutpb: 0.71
# Geração 18 - cxpb: 0.29, mutpb: 0.71
# Geração 19 - cxpb: 0.29, mutpb: 0.71
# Geração 20 - cxpb: 0.29, mutpb: 0.71
# Geração 21 - cxpb: 0.29, mutpb: 0.71
# Geração 22 - cxpb: 0.29, mutpb: 0.71
# Geração 23 - cxpb: 0.29, mutpb: 0.71
# Geração 24 - cxpb: 0.29, mutpb: 0.71
# Geração 25 - cxpb: 0.29, mutpb: 0.71
# Geração 26 - cxpb: 0.29, mutpb: 0.71
# Geração 27 - cxpb: 0.29, mutpb: 0.71
# Geração 28 - cxpb: 0.29, mutpb: 0.71
# Geração 29 - cxpb: 0.29, mutpb: 0.71
# Geração 30 - cxpb: 0.29, mutpb: 0.71
# Geração 31 - cxpb: 0.29, mutpb: 0.71
# Geração 32 - cxpb: 0.29, mutpb: 0.71
# Geração 33 - cxpb: 0.29, mutpb: 0.71
# Geração 34 - cxpb: 0.29, mutpb: 0.71
# Geração 35 - cxpb: 0.29, mutpb: 0.71
# Geração 36 - cxpb: 0.29, mutpb: 0.71
# Geração 37 - cxpb: 0.29, mutpb: 0.71
# Geração 38 - cxpb: 0.28, mutpb: 0.72
# Geração 39 - cxpb: 0.28, mutpb: 0.72
# Geração 40 - cxpb: 0.28, mutpb: 0.72
# Geração 41 - cxpb: 0.28, mutpb: 0.72
# Geração 42 - cxpb: 0.28, mutpb: 0.72
# Geração 43 - cxpb: 0.28, mutpb: 0.72
# Geração 44 - cxpb: 0.28, mutpb: 0.72
# Geração 45 - cxpb: 0.28, mutpb: 0.72
# Geração 46 - cxpb: 0.28, mutpb: 0.72
# Geração 47 - cxpb: 0.28, mutpb: 0.72
# Geração 48 - cxpb: 0.28, mutpb: 0.72
# Geração 49 - cxpb: 0.28, mutpb: 0.72
# Geração 50 - cxpb: 0.28, mutpb: 0.72
# Geração 51 - cxpb: 0.28, mutpb: 0.72
# Geração 52 - cxpb: 0.28, mutpb: 0.72
# Geração 53 - cxpb: 0.28, mutpb: 0.72
# Geração 54 - cxpb: 0.28, mutpb: 0.72
# Geração 55 - cxpb: 0.28, mutpb: 0.72
# Geração 56 - cxpb: 0.28, mutpb: 0.72
# Geração 57 - cxpb: 0.28, mutpb: 0.72
# Geração 58 - cxpb: 0.28, mutpb: 0.72
# Geração 59 - cxpb: 0.28, mutpb: 0.72
# Geração 60 - cxpb: 0.28, mutpb: 0.72
# Geração 61 - cxpb: 0.28, mutpb: 0.72
# Geração 62 - cxpb: 0.28, mutpb: 0.72
# Geração 63 - cxpb: 0.27, mutpb: 0.73
# Geração 64 - cxpb: 0.27, mutpb: 0.73
# Geração 65 - cxpb: 0.27, mutpb: 0.73
# Geração 66 - cxpb: 0.27, mutpb: 0.73
# Geração 67 - cxpb: 0.27, mutpb: 0.73
# Geração 68 - cxpb: 0.27, mutpb: 0.73
# Geração 69 - cxpb: 0.27, mutpb: 0.73
# Geração 70 - cxpb: 0.27, mutpb: 0.73
# Geração 71 - cxpb: 0.27, mutpb: 0.73
# Geração 72 - cxpb: 0.27, mutpb: 0.73
# Geração 73 - cxpb: 0.27, mutpb: 0.73
# Geração 74 - cxpb: 0.27, mutpb: 0.73
# Geração 75 - cxpb: 0.27, mutpb: 0.73
# Geração 76 - cxpb: 0.27, mutpb: 0.73
# Geração 77 - cxpb: 0.27, mutpb: 0.73
# Geração 78 - cxpb: 0.27, mutpb: 0.73
# Geração 79 - cxpb: 0.27, mutpb: 0.73
# Geração 80 - cxpb: 0.27, mutpb: 0.73
# Geração 81 - cxpb: 0.27, mutpb: 0.73
# Geração 82 - cxpb: 0.27, mutpb: 0.73
# Geração 83 - cxpb: 0.27, mutpb: 0.73
# Geração 84 - cxpb: 0.27, mutpb: 0.73
# Geração 85 - cxpb: 0.27, mutpb: 0.73
# Geração 86 - cxpb: 0.27, mutpb: 0.73
# Geração 87 - cxpb: 0.27, mutpb: 0.73
# Geração 88 - cxpb: 0.26, mutpb: 0.74
# Geração 89 - cxpb: 0.26, mutpb: 0.74
# Geração 90 - cxpb: 0.26, mutpb: 0.74
# Geração 91 - cxpb: 0.26, mutpb: 0.74
# Geração 92 - cxpb: 0.26, mutpb: 0.74
# Geração 93 - cxpb: 0.26, mutpb: 0.74
# Geração 94 - cxpb: 0.26, mutpb: 0.74
# Geração 95 - cxpb: 0.26, mutpb: 0.74
# Geração 96 - cxpb: 0.26, mutpb: 0.74
# Geração 97 - cxpb: 0.26, mutpb: 0.74
# Geração 98 - cxpb: 0.26, mutpb: 0.74
# Geração 99 - cxpb: 0.26, mutpb: 0.74
# Geração 100 - cxpb: 0.26, mutpb: 0.74
# Geração 101 - cxpb: 0.26, mutpb: 0.74
# Geração 102 - cxpb: 0.26, mutpb: 0.74
# Geração 103 - cxpb: 0.26, mutpb: 0.74
# Geração 104 - cxpb: 0.26, mutpb: 0.74
# Geração 105 - cxpb: 0.26, mutpb: 0.74
# Geração 106 - cxpb: 0.26, mutpb: 0.74
# Geração 107 - cxpb: 0.26, mutpb: 0.74
# Geração 108 - cxpb: 0.26, mutpb: 0.74
# Geração 109 - cxpb: 0.26, mutpb: 0.74
# Geração 110 - cxpb: 0.26, mutpb: 0.74
# Geração 111 - cxpb: 0.26, mutpb: 0.74
# Geração 112 - cxpb: 0.26, mutpb: 0.74
# Geração 113 - cxpb: 0.25, mutpb: 0.75
# Geração 114 - cxpb: 0.25, mutpb: 0.75
# Geração 115 - cxpb: 0.25, mutpb: 0.75
# Geração 116 - cxpb: 0.25, mutpb: 0.75
# Geração 117 - cxpb: 0.25, mutpb: 0.75
# Geração 118 - cxpb: 0.25, mutpb: 0.75
# Geração 119 - cxpb: 0.25, mutpb: 0.75
# Geração 120 - cxpb: 0.25, mutpb: 0.75
# Geração 121 - cxpb: 0.25, mutpb: 0.75
# Geração 122 - cxpb: 0.25, mutpb: 0.75
# Geração 123 - cxpb: 0.25, mutpb: 0.75
# Geração 124 - cxpb: 0.25, mutpb: 0.75
# Geração 125 - cxpb: 0.25, mutpb: 0.75
# Geração 126 - cxpb: 0.25, mutpb: 0.75
# Geração 127 - cxpb: 0.25, mutpb: 0.75
# Geração 128 - cxpb: 0.25, mutpb: 0.75
# Geração 129 - cxpb: 0.25, mutpb: 0.75
# Geração 130 - cxpb: 0.25, mutpb: 0.75
# Geração 131 - cxpb: 0.25, mutpb: 0.75
# Geração 132 - cxpb: 0.25, mutpb: 0.75
# Geração 133 - cxpb: 0.25, mutpb: 0.75
# Geração 134 - cxpb: 0.25, mutpb: 0.75
# Geração 135 - cxpb: 0.25, mutpb: 0.75
# Geração 136 - cxpb: 0.25, mutpb: 0.75
# Geração 137 - cxpb: 0.25, mutpb: 0.75
# Geração 138 - cxpb: 0.24, mutpb: 0.76
# Geração 139 - cxpb: 0.24, mutpb: 0.76
# Geração 140 - cxpb: 0.24, mutpb: 0.76
# Geração 141 - cxpb: 0.24, mutpb: 0.76
# Geração 142 - cxpb: 0.24, mutpb: 0.76
# Geração 143 - cxpb: 0.24, mutpb: 0.76
# Geração 144 - cxpb: 0.24, mutpb: 0.76
# Geração 145 - cxpb: 0.24, mutpb: 0.76
# Geração 146 - cxpb: 0.24, mutpb: 0.76
# Geração 147 - cxpb: 0.24, mutpb: 0.76
# Geração 148 - cxpb: 0.24, mutpb: 0.76
# Geração 149 - cxpb: 0.24, mutpb: 0.76
# Geração 150 - cxpb: 0.24, mutpb: 0.76
# Geração 151 - cxpb: 0.24, mutpb: 0.76
# Geração 152 - cxpb: 0.24, mutpb: 0.76
# Geração 153 - cxpb: 0.24, mutpb: 0.76
# Geração 154 - cxpb: 0.24, mutpb: 0.76
# Geração 155 - cxpb: 0.24, mutpb: 0.76
# Geração 156 - cxpb: 0.24, mutpb: 0.76
# Geração 157 - cxpb: 0.24, mutpb: 0.76
# Geração 158 - cxpb: 0.24, mutpb: 0.76
# Geração 159 - cxpb: 0.24, mutpb: 0.76
# Geração 160 - cxpb: 0.24, mutpb: 0.76
# Geração 161 - cxpb: 0.24, mutpb: 0.76
# Geração 162 - cxpb: 0.24, mutpb: 0.76
# Geração 163 - cxpb: 0.23, mutpb: 0.77
# Geração 164 - cxpb: 0.23, mutpb: 0.77
# Geração 165 - cxpb: 0.23, mutpb: 0.77
# Geração 166 - cxpb: 0.23, mutpb: 0.77
# Geração 167 - cxpb: 0.23, mutpb: 0.77
# Geração 168 - cxpb: 0.23, mutpb: 0.77
# Geração 169 - cxpb: 0.23, mutpb: 0.77
# Geração 170 - cxpb: 0.23, mutpb: 0.77
# Geração 171 - cxpb: 0.23, mutpb: 0.77
# Geração 172 - cxpb: 0.23, mutpb: 0.77
# Geração 173 - cxpb: 0.23, mutpb: 0.77
# Geração 174 - cxpb: 0.23, mutpb: 0.77
# Geração 175 - cxpb: 0.23, mutpb: 0.77
# Geração 176 - cxpb: 0.23, mutpb: 0.77
# Geração 177 - cxpb: 0.23, mutpb: 0.77
# Geração 178 - cxpb: 0.23, mutpb: 0.77
# Geração 179 - cxpb: 0.23, mutpb: 0.77
# Geração 180 - cxpb: 0.23, mutpb: 0.77
# Geração 181 - cxpb: 0.23, mutpb: 0.77
# Geração 182 - cxpb: 0.23, mutpb: 0.77
# Geração 183 - cxpb: 0.23, mutpb: 0.77
# Geração 184 - cxpb: 0.23, mutpb: 0.77
# Geração 185 - cxpb: 0.23, mutpb: 0.77
# Geração 186 - cxpb: 0.23, mutpb: 0.77
# Geração 187 - cxpb: 0.23, mutpb: 0.77
# Geração 188 - cxpb: 0.22, mutpb: 0.78
# Geração 189 - cxpb: 0.22, mutpb: 0.78
# Geração 190 - cxpb: 0.22, mutpb: 0.78
# Geração 191 - cxpb: 0.22, mutpb: 0.78
# Geração 192 - cxpb: 0.22, mutpb: 0.78
# Geração 193 - cxpb: 0.22, mutpb: 0.78
# Geração 194 - cxpb: 0.22, mutpb: 0.78
# Geração 195 - cxpb: 0.22, mutpb: 0.78
# Geração 196 - cxpb: 0.22, mutpb: 0.78
# Geração 197 - cxpb: 0.22, mutpb: 0.78
# Geração 198 - cxpb: 0.22, mutpb: 0.78
# Geração 199 - cxpb: 0.22, mutpb: 0.78
# Geração 200 - cxpb: 0.22, mutpb: 0.78
# Geração 201 - cxpb: 0.22, mutpb: 0.78
# Geração 202 - cxpb: 0.22, mutpb: 0.78
# Geração 203 - cxpb: 0.22, mutpb: 0.78
# Geração 204 - cxpb: 0.22, mutpb: 0.78
# Geração 205 - cxpb: 0.22, mutpb: 0.78
# Geração 206 - cxpb: 0.22, mutpb: 0.78
# Geração 207 - cxpb: 0.22, mutpb: 0.78
# Geração 208 - cxpb: 0.22, mutpb: 0.78
# Geração 209 - cxpb: 0.22, mutpb: 0.78
# Geração 210 - cxpb: 0.22, mutpb: 0.78
# Geração 211 - cxpb: 0.22, mutpb: 0.78
# Geração 212 - cxpb: 0.22, mutpb: 0.78
# Geração 213 - cxpb: 0.21, mutpb: 0.79
# Geração 214 - cxpb: 0.21, mutpb: 0.79
# Geração 215 - cxpb: 0.21, mutpb: 0.79
# Geração 216 - cxpb: 0.21, mutpb: 0.79
# Geração 217 - cxpb: 0.21, mutpb: 0.79
# Geração 218 - cxpb: 0.21, mutpb: 0.79
# Geração 219 - cxpb: 0.21, mutpb: 0.79
# Geração 220 - cxpb: 0.21, mutpb: 0.79
# Geração 221 - cxpb: 0.21, mutpb: 0.79
# Geração 222 - cxpb: 0.21, mutpb: 0.79
# Geração 223 - cxpb: 0.21, mutpb: 0.79
# Geração 224 - cxpb: 0.21, mutpb: 0.79
# Geração 225 - cxpb: 0.21, mutpb: 0.79
# Geração 226 - cxpb: 0.21, mutpb: 0.79
# Geração 227 - cxpb: 0.21, mutpb: 0.79
# Geração 228 - cxpb: 0.21, mutpb: 0.79
# Geração 229 - cxpb: 0.21, mutpb: 0.79
# Geração 230 - cxpb: 0.21, mutpb: 0.79
# Geração 231 - cxpb: 0.21, mutpb: 0.79
# Geração 232 - cxpb: 0.21, mutpb: 0.79
# Geração 233 - cxpb: 0.21, mutpb: 0.79
# Geração 234 - cxpb: 0.21, mutpb: 0.79
# Geração 235 - cxpb: 0.21, mutpb: 0.79
# Geração 236 - cxpb: 0.21, mutpb: 0.79
# Geração 237 - cxpb: 0.21, mutpb: 0.79
# Geração 238 - cxpb: 0.20, mutpb: 0.80
# Geração 239 - cxpb: 0.20, mutpb: 0.80
# Geração 240 - cxpb: 0.20, mutpb: 0.80
# Geração 241 - cxpb: 0.20, mutpb: 0.80
# Geração 242 - cxpb: 0.20, mutpb: 0.80
# Geração 243 - cxpb: 0.20, mutpb: 0.80
# Geração 244 - cxpb: 0.20, mutpb: 0.80
# Geração 245 - cxpb: 0.20, mutpb: 0.80
# Geração 246 - cxpb: 0.20, mutpb: 0.80
# Geração 247 - cxpb: 0.20, mutpb: 0.80
# Geração 248 - cxpb: 0.20, mutpb: 0.80
# Geração 249 - cxpb: 0.20, mutpb: 0.80
# Geração 250 - cxpb: 0.20, mutpb: 0.80
# Geração 251 - cxpb: 0.20, mutpb: 0.80
# Geração 252 - cxpb: 0.20, mutpb: 0.80
# Geração 253 - cxpb: 0.20, mutpb: 0.80
# Geração 254 - cxpb: 0.20, mutpb: 0.80
# Geração 255 - cxpb: 0.20, mutpb: 0.80
# Geração 256 - cxpb: 0.20, mutpb: 0.80
# Geração 257 - cxpb: 0.20, mutpb: 0.80
# Geração 258 - cxpb: 0.20, mutpb: 0.80
# Geração 259 - cxpb: 0.20, mutpb: 0.80
# Geração 260 - cxpb: 0.20, mutpb: 0.80
# Geração 261 - cxpb: 0.20, mutpb: 0.80
# Geração 262 - cxpb: 0.20, mutpb: 0.80
# Geração 263 - cxpb: 0.19, mutpb: 0.81
# Geração 264 - cxpb: 0.19, mutpb: 0.81
# Geração 265 - cxpb: 0.19, mutpb: 0.81
# Geração 266 - cxpb: 0.19, mutpb: 0.81
# Geração 267 - cxpb: 0.19, mutpb: 0.81
# Geração 268 - cxpb: 0.19, mutpb: 0.81
# Geração 269 - cxpb: 0.19, mutpb: 0.81
# Geração 270 - cxpb: 0.19, mutpb: 0.81
# Geração 271 - cxpb: 0.19, mutpb: 0.81
# Geração 272 - cxpb: 0.19, mutpb: 0.81
# Geração 273 - cxpb: 0.19, mutpb: 0.81
# Geração 274 - cxpb: 0.19, mutpb: 0.81
# Geração 275 - cxpb: 0.19, mutpb: 0.81
# Geração 276 - cxpb: 0.19, mutpb: 0.81
# Geração 277 - cxpb: 0.19, mutpb: 0.81
# Geração 278 - cxpb: 0.19, mutpb: 0.81
# Geração 279 - cxpb: 0.19, mutpb: 0.81
# Geração 280 - cxpb: 0.19, mutpb: 0.81
# Geração 281 - cxpb: 0.19, mutpb: 0.81
# Geração 282 - cxpb: 0.19, mutpb: 0.81
# Geração 283 - cxpb: 0.19, mutpb: 0.81
# Geração 284 - cxpb: 0.19, mutpb: 0.81
# Geração 285 - cxpb: 0.19, mutpb: 0.81
# Geração 286 - cxpb: 0.19, mutpb: 0.81
# Geração 287 - cxpb: 0.19, mutpb: 0.81
# Geração 288 - cxpb: 0.18, mutpb: 0.82
# Geração 289 - cxpb: 0.18, mutpb: 0.82
# Geração 290 - cxpb: 0.18, mutpb: 0.82
# Geração 291 - cxpb: 0.18, mutpb: 0.82
# Geração 292 - cxpb: 0.18, mutpb: 0.82
# Geração 293 - cxpb: 0.18, mutpb: 0.82
# Geração 294 - cxpb: 0.18, mutpb: 0.82
# Geração 295 - cxpb: 0.18, mutpb: 0.82
# Geração 296 - cxpb: 0.18, mutpb: 0.82
# Geração 297 - cxpb: 0.18, mutpb: 0.82
# Geração 298 - cxpb: 0.18, mutpb: 0.82
# Geração 299 - cxpb: 0.18, mutpb: 0.82
# Geração 300 - cxpb: 0.18, mutpb: 0.82
# Geração 301 - cxpb: 0.18, mutpb: 0.82
# Geração 302 - cxpb: 0.18, mutpb: 0.82
# Geração 303 - cxpb: 0.18, mutpb: 0.82
# Geração 304 - cxpb: 0.18, mutpb: 0.82
# Geração 305 - cxpb: 0.18, mutpb: 0.82
# Geração 306 - cxpb: 0.18, mutpb: 0.82
# Geração 307 - cxpb: 0.18, mutpb: 0.82
# Geração 308 - cxpb: 0.18, mutpb: 0.82
# Geração 309 - cxpb: 0.18, mutpb: 0.82
# Geração 310 - cxpb: 0.18, mutpb: 0.82
# Geração 311 - cxpb: 0.18, mutpb: 0.82
# Geração 312 - cxpb: 0.18, mutpb: 0.82
# Geração 313 - cxpb: 0.17, mutpb: 0.83
# Geração 314 - cxpb: 0.17, mutpb: 0.83
# Geração 315 - cxpb: 0.17, mutpb: 0.83
# Geração 316 - cxpb: 0.17, mutpb: 0.83
# Geração 317 - cxpb: 0.17, mutpb: 0.83
# Geração 318 - cxpb: 0.17, mutpb: 0.83
# Geração 319 - cxpb: 0.17, mutpb: 0.83
# Geração 320 - cxpb: 0.17, mutpb: 0.83
# Geração 321 - cxpb: 0.17, mutpb: 0.83
# Geração 322 - cxpb: 0.17, mutpb: 0.83
# Geração 323 - cxpb: 0.17, mutpb: 0.83
# Geração 324 - cxpb: 0.17, mutpb: 0.83
# Geração 325 - cxpb: 0.17, mutpb: 0.83
# Geração 326 - cxpb: 0.17, mutpb: 0.83
# Geração 327 - cxpb: 0.17, mutpb: 0.83
# Geração 328 - cxpb: 0.17, mutpb: 0.83
# Geração 329 - cxpb: 0.17, mutpb: 0.83
# Geração 330 - cxpb: 0.17, mutpb: 0.83
# Geração 331 - cxpb: 0.17, mutpb: 0.83
# Geração 332 - cxpb: 0.17, mutpb: 0.83
# Geração 333 - cxpb: 0.17, mutpb: 0.83
# Geração 334 - cxpb: 0.17, mutpb: 0.83
# Geração 335 - cxpb: 0.17, mutpb: 0.83
# Geração 336 - cxpb: 0.17, mutpb: 0.83
# Geração 337 - cxpb: 0.17, mutpb: 0.83
# Geração 338 - cxpb: 0.16, mutpb: 0.84
# Geração 339 - cxpb: 0.16, mutpb: 0.84
# Geração 340 - cxpb: 0.16, mutpb: 0.84
# Geração 341 - cxpb: 0.16, mutpb: 0.84
# Geração 342 - cxpb: 0.16, mutpb: 0.84
# Geração 343 - cxpb: 0.16, mutpb: 0.84
# Geração 344 - cxpb: 0.16, mutpb: 0.84
# Geração 345 - cxpb: 0.16, mutpb: 0.84
# Geração 346 - cxpb: 0.16, mutpb: 0.84
# Geração 347 - cxpb: 0.16, mutpb: 0.84
# Geração 348 - cxpb: 0.16, mutpb: 0.84
# Geração 349 - cxpb: 0.16, mutpb: 0.84
# Geração 350 - cxpb: 0.16, mutpb: 0.84
# Geração 351 - cxpb: 0.16, mutpb: 0.84
# Geração 352 - cxpb: 0.16, mutpb: 0.84
# Geração 353 - cxpb: 0.16, mutpb: 0.84
# Geração 354 - cxpb: 0.16, mutpb: 0.84
# Geração 355 - cxpb: 0.16, mutpb: 0.84
# Geração 356 - cxpb: 0.16, mutpb: 0.84
# Geração 357 - cxpb: 0.16, mutpb: 0.84
# Geração 358 - cxpb: 0.16, mutpb: 0.84
# Geração 359 - cxpb: 0.16, mutpb: 0.84
# Geração 360 - cxpb: 0.16, mutpb: 0.84
# Geração 361 - cxpb: 0.16, mutpb: 0.84
# Geração 362 - cxpb: 0.16, mutpb: 0.84
# Geração 363 - cxpb: 0.15, mutpb: 0.85
# Geração 364 - cxpb: 0.15, mutpb: 0.85
# Geração 365 - cxpb: 0.15, mutpb: 0.85
# Geração 366 - cxpb: 0.15, mutpb: 0.85
# Geração 367 - cxpb: 0.15, mutpb: 0.85
# Geração 368 - cxpb: 0.15, mutpb: 0.85
# Geração 369 - cxpb: 0.15, mutpb: 0.85
# Geração 370 - cxpb: 0.15, mutpb: 0.85
# Geração 371 - cxpb: 0.15, mutpb: 0.85
# Geração 372 - cxpb: 0.15, mutpb: 0.85
# Geração 373 - cxpb: 0.15, mutpb: 0.85
# Geração 374 - cxpb: 0.15, mutpb: 0.85
# Geração 375 - cxpb: 0.15, mutpb: 0.85
# Geração 376 - cxpb: 0.15, mutpb: 0.85
# Geração 377 - cxpb: 0.15, mutpb: 0.85
# Geração 378 - cxpb: 0.15, mutpb: 0.85
# Geração 379 - cxpb: 0.15, mutpb: 0.85
# Geração 380 - cxpb: 0.15, mutpb: 0.85
# Geração 381 - cxpb: 0.15, mutpb: 0.85
# Geração 382 - cxpb: 0.15, mutpb: 0.85
# Geração 383 - cxpb: 0.15, mutpb: 0.85
# Geração 384 - cxpb: 0.15, mutpb: 0.85
# Geração 385 - cxpb: 0.15, mutpb: 0.85
# Geração 386 - cxpb: 0.15, mutpb: 0.85
# Geração 387 - cxpb: 0.15, mutpb: 0.85
# Geração 388 - cxpb: 0.14, mutpb: 0.86
# Geração 389 - cxpb: 0.14, mutpb: 0.86
# Geração 390 - cxpb: 0.14, mutpb: 0.86
# Geração 391 - cxpb: 0.14, mutpb: 0.86
# Geração 392 - cxpb: 0.14, mutpb: 0.86
# Geração 393 - cxpb: 0.14, mutpb: 0.86
# Geração 394 - cxpb: 0.14, mutpb: 0.86
# Geração 395 - cxpb: 0.14, mutpb: 0.86
# Geração 396 - cxpb: 0.14, mutpb: 0.86
# Geração 397 - cxpb: 0.14, mutpb: 0.86
# Geração 398 - cxpb: 0.14, mutpb: 0.86
# Geração 399 - cxpb: 0.14, mutpb: 0.86
# Geração 400 - cxpb: 0.14, mutpb: 0.86
# Geração 401 - cxpb: 0.14, mutpb: 0.86
# Geração 402 - cxpb: 0.14, mutpb: 0.86
# Geração 403 - cxpb: 0.14, mutpb: 0.86
# Geração 404 - cxpb: 0.14, mutpb: 0.86
# Geração 405 - cxpb: 0.14, mutpb: 0.86
# Geração 406 - cxpb: 0.14, mutpb: 0.86
# Geração 407 - cxpb: 0.14, mutpb: 0.86
# Geração 408 - cxpb: 0.14, mutpb: 0.86
# Geração 409 - cxpb: 0.14, mutpb: 0.86
# Geração 410 - cxpb: 0.14, mutpb: 0.86
# Geração 411 - cxpb: 0.14, mutpb: 0.86
# Geração 412 - cxpb: 0.14, mutpb: 0.86
# Geração 413 - cxpb: 0.13, mutpb: 0.87
# Geração 414 - cxpb: 0.13, mutpb: 0.87
# Geração 415 - cxpb: 0.13, mutpb: 0.87
# Geração 416 - cxpb: 0.13, mutpb: 0.87
# Geração 417 - cxpb: 0.13, mutpb: 0.87
# Geração 418 - cxpb: 0.13, mutpb: 0.87
# Geração 419 - cxpb: 0.13, mutpb: 0.87
# Geração 420 - cxpb: 0.13, mutpb: 0.87
# Geração 421 - cxpb: 0.13, mutpb: 0.87
# Geração 422 - cxpb: 0.13, mutpb: 0.87
# Geração 423 - cxpb: 0.13, mutpb: 0.87
# Geração 424 - cxpb: 0.13, mutpb: 0.87
# Geração 425 - cxpb: 0.13, mutpb: 0.87
# Geração 426 - cxpb: 0.13, mutpb: 0.87
# Geração 427 - cxpb: 0.13, mutpb: 0.87
# Geração 428 - cxpb: 0.13, mutpb: 0.87
# Geração 429 - cxpb: 0.13, mutpb: 0.87
# Geração 430 - cxpb: 0.13, mutpb: 0.87
# Geração 431 - cxpb: 0.13, mutpb: 0.87
# Geração 432 - cxpb: 0.13, mutpb: 0.87
# Geração 433 - cxpb: 0.13, mutpb: 0.87
# Geração 434 - cxpb: 0.13, mutpb: 0.87
# Geração 435 - cxpb: 0.13, mutpb: 0.87
# Geração 436 - cxpb: 0.13, mutpb: 0.87
# Geração 437 - cxpb: 0.13, mutpb: 0.87
# Geração 438 - cxpb: 0.12, mutpb: 0.88
# Geração 439 - cxpb: 0.12, mutpb: 0.88
# Geração 440 - cxpb: 0.12, mutpb: 0.88
# Geração 441 - cxpb: 0.12, mutpb: 0.88
# Geração 442 - cxpb: 0.12, mutpb: 0.88
# Geração 443 - cxpb: 0.12, mutpb: 0.88
# Geração 444 - cxpb: 0.12, mutpb: 0.88
# Geração 445 - cxpb: 0.12, mutpb: 0.88
# Geração 446 - cxpb: 0.12, mutpb: 0.88
# Geração 447 - cxpb: 0.12, mutpb: 0.88
# Geração 448 - cxpb: 0.12, mutpb: 0.88
# Geração 449 - cxpb: 0.12, mutpb: 0.88
# Geração 450 - cxpb: 0.12, mutpb: 0.88
# Geração 451 - cxpb: 0.12, mutpb: 0.88
# Geração 452 - cxpb: 0.12, mutpb: 0.88
# Geração 453 - cxpb: 0.12, mutpb: 0.88
# Geração 454 - cxpb: 0.12, mutpb: 0.88
# Geração 455 - cxpb: 0.12, mutpb: 0.88
# Geração 456 - cxpb: 0.12, mutpb: 0.88
# Geração 457 - cxpb: 0.12, mutpb: 0.88
# Geração 458 - cxpb: 0.12, mutpb: 0.88
# Geração 459 - cxpb: 0.12, mutpb: 0.88
# Geração 460 - cxpb: 0.12, mutpb: 0.88
# Geração 461 - cxpb: 0.12, mutpb: 0.88
# Geração 462 - cxpb: 0.12, mutpb: 0.88
# Geração 463 - cxpb: 0.11, mutpb: 0.89
# Geração 464 - cxpb: 0.11, mutpb: 0.89
# Geração 465 - cxpb: 0.11, mutpb: 0.89
# Geração 466 - cxpb: 0.11, mutpb: 0.89
# Geração 467 - cxpb: 0.11, mutpb: 0.89
# Geração 468 - cxpb: 0.11, mutpb: 0.89
# Geração 469 - cxpb: 0.11, mutpb: 0.89
# Geração 470 - cxpb: 0.11, mutpb: 0.89
# Geração 471 - cxpb: 0.11, mutpb: 0.89
# Geração 472 - cxpb: 0.11, mutpb: 0.89
# Geração 473 - cxpb: 0.11, mutpb: 0.89
# Geração 474 - cxpb: 0.11, mutpb: 0.89
# Geração 475 - cxpb: 0.11, mutpb: 0.89
# Geração 476 - cxpb: 0.11, mutpb: 0.89
# Geração 477 - cxpb: 0.11, mutpb: 0.89
# Geração 478 - cxpb: 0.11, mutpb: 0.89
# Geração 479 - cxpb: 0.11, mutpb: 0.89
# Geração 480 - cxpb: 0.11, mutpb: 0.89
# Geração 481 - cxpb: 0.11, mutpb: 0.89
# Geração 482 - cxpb: 0.11, mutpb: 0.89
# Geração 483 - cxpb: 0.11, mutpb: 0.89
# Geração 484 - cxpb: 0.11, mutpb: 0.89
# Geração 485 - cxpb: 0.11, mutpb: 0.89
# Geração 486 - cxpb: 0.11, mutpb: 0.89
# Geração 487 - cxpb: 0.11, mutpb: 0.89
# Geração 488 - cxpb: 0.10, mutpb: 0.90
# Geração 489 - cxpb: 0.10, mutpb: 0.90
# Geração 490 - cxpb: 0.10, mutpb: 0.90
# Geração 491 - cxpb: 0.10, mutpb: 0.90
# Geração 492 - cxpb: 0.10, mutpb: 0.90
# Geração 493 - cxpb: 0.10, mutpb: 0.90
# Geração 494 - cxpb: 0.10, mutpb: 0.90
# Geração 495 - cxpb: 0.10, mutpb: 0.90
# Geração 496 - cxpb: 0.10, mutpb: 0.90
# Geração 497 - cxpb: 0.10, mutpb: 0.90
# Geração 498 - cxpb: 0.10, mutpb: 0.90
# Geração 499 - cxpb: 0.10, mutpb: 0.90
# Geração 500 - cxpb: 0.10, mutpb: 0.90
# Indivíduo 1 - Retorno: 0.19667, CVaR: 0.12125
# Indivíduo 2 - Retorno: 0.19667, CVaR: 0.12125
# Indivíduo 3 - Retorno: 0.19667, CVaR: 0.12125
# Indivíduo 4 - Retorno: 0.19667, CVaR: 0.12125
# Indivíduo 5 - Retorno: 0.19667, CVaR: 0.12125

# %%
# Selecionar os 5 melhores indivíduos
melhores_inds = tools.selBest(pop, k=5)

for idx, ind in enumerate(melhores_inds, start=1):
    # Separar pesos e seleção
    pesos = np.array(ind[:n_ativos])
    selecionados = np.array(ind[n_ativos:])
    pesos = pesos * selecionados

    # Normalizar os pesos (se soma > 0)
    soma_pesos = pesos.sum()
    if soma_pesos > 0:
        pesos = pesos / soma_pesos

    # Criar dicionário com os ativos selecionados
    portfolio = {
        ticker: peso for ticker, peso, sel in zip(tickers, pesos, selecionados) if sel == 1
    }

    # Imprimir resultados
    print(f"\nIndivíduo {idx} - Retorno: {avaliar(ind)[0]:.5f}, CVaR: {avaliar(ind)[1]:.5f}")
    print("Portfólio (pesos normalizados):")
    for ticker, peso in portfolio.items():
        print(f"  {ticker}: {peso:.4f}")
# Out:
# Indivíduo 1 - Retorno: 0.19667, CVaR: 0.12125
# Portfólio (pesos normalizados):
#   ACTX: 0.2385
#   AFLG: 0.0137
#   AGNG: 0.1617
#   AIEQ: 0.2729
#   AIVI: 0.1944
#   AMZA: 0.1187
#
# Indivíduo 2 - Retorno: 0.19667, CVaR: 0.12125
# Portfólio (pesos normalizados):
#   ACTX: 0.2385
#   AFLG: 0.0137
#   AGNG: 0.1617
#   AIEQ: 0.2729
#   AIVI: 0.1944
#   AMZA: 0.1187
#
# Indivíduo 3 - Retorno: 0.19667, CVaR: 0.12125
# Portfólio (pesos normalizados):
#   ACTX: 0.2385
#   AFLG: 0.0137
#   AGNG: 0.1617
#   AIEQ: 0.2729
#   AIVI: 0.1944
#   AMZA: 0.1187
#
# Indivíduo 4 - Retorno: 0.19667, CVaR: 0.12125
# Portfólio (pesos normalizados):
#   ACTX: 0.2385
#   AFLG: 0.0137
#   AGNG: 0.1617
#   AIEQ: 0.2729
#   AIVI: 0.1944
#   AMZA: 0.1187
#
# Indivíduo 5 - Retorno: 0.19667, CVaR: 0.12125
# Portfólio (pesos normalizados):
#   ACTX: 0.2385
#   AFLG: 0.0137
#   AGNG: 0.1617
#   AIEQ: 0.2729
#   AIVI: 0.1944
#   AMZA: 0.1187
